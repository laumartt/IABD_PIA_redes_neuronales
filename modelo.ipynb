# %% [markdown]
# Una red

# %%
from tabulate import tabulate
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from matplotlib.colors import LightSource
import random

'''CARGA DATOS, x,y
iris=load_iris()

sepal_length=iris.data[0:99,0]
petal_length=iris.data[0:99,2]
flower_type=iris.target[0:99]

x=np.column_stack((sepal_length,petal_length))
y=flower_type'''


np.random.seed(5)
tf.random.set_seed(5)
random.seed(5)

def fit_compile(capas, x, y, epocas=40):

    model=Sequential()
    model.add(Dense(capas[0], activation='relu',input_dim=2))
    for i in range(1,len(capas)-2):
      model.add(Dense(capas[i], activation='relu'))

    model.add(Dense(capas[-1], activation='sigmoid'))
    model.compile(loss='mean_squared_error')

    model.fit(x, y,epochs=epocas)

    return model



model=fit_compile([2,  4 , 1], x, y)
resultados1=model.predict(np.array([[4.9,1.4]]))
resultados2=model.predict(np.array([[6.3,4.9]]))
print(resultados1)

print(resultados2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 43
#      37     model.fit(x, y,epochs=epocas)
#      39     return model
# ---> 43 model=fit_compile([2,  4 , 1], x, y)
#      44 resultados1=model.predict(np.array([[4.9,1.4]]))
#      45 resultados2=model.predict(np.array([[6.3,4.9]]))
#
# NameError: name 'x' is not defined

# %% [markdown]
# Varias redes

# %%
from tabulate import tabulate
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from matplotlib.colors import LightSource
import random

'''CARGA DATOS, x,y
iris=load_iris()

sepal_length=iris.data[0:99,0]
petal_length=iris.data[0:99,2]
flower_type=iris.target[0:99]

x=np.column_stack((sepal_length,petal_length))
y=flower_type'''


np.random.seed(5)
tf.random.set_seed(5)
random.seed(5)

def fit_compile(capas, x, y, epocas=40):

    model=Sequential()
    model.add(Dense(capas[0], activation='relu',input_dim=2))
    for i in range(1,len(capas)-2):
      model.add(Dense(capas[i], activation='relu'))

    model.add(Dense(capas[-1], activation='sigmoid'))
    model.compile(loss='mean_squared_error')

    model.fit(x, y,epochs=epocas)

    return model

'''Varias redes
redes=[[2,  4 , 1], [4,  8, 8, 2, 1], [8, 12, 24, 12, 1], [8, 16, 8, 1], [16, 32, 1]]'''

resultados=[]

for i in range(0,len(redes)-1):
  model=fit_compile(redes[i], x, y)
  resultados1=model.predict(np.array([[4.9,1.4]]))
  resultados2=model.predict(np.array([[6.3,4.9]]))
  index=i+1
  resultados.append([index, resultados1,resultados2])
  print(resultados)

print(resultados)
print('\n-----------------------------\n')
print(tabulate(resultados, headers=('indice', 'resultados1', 'resultados2')))

# %% [markdown]
# Varias redes y varias predicciones

# %%
from tabulate import tabulate
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from matplotlib.colors import LightSource
import random

'''CARGA DATOS, x,y'''
iris=load_iris()

sepal_length=iris.data[0:99,0]
petal_length=iris.data[0:99,2]
flower_type=iris.target[0:99]

x=np.column_stack((sepal_length,petal_length))
y=flower_type


np.random.seed(5)
tf.random.set_seed(5)
random.seed(5)

def fit_compile(capas, x, y, epocas=40):

    model=Sequential()
    model.add(Dense(capas[0], activation='relu',input_dim=2))
    for i in range(1,len(capas)-2):
      model.add(Dense(capas[i], activation='relu'))

    model.add(Dense(capas[-1], activation='sigmoid'))
    model.compile(loss='mean_squared_error')

    model.fit(x, y,epochs=epocas)

    return model


redes=[[2,  4 , 1], [4,  8, 8, 2, 1], [8, 12, 24, 12, 1], [8, 16, 8, 1], [16, 32, 1]]
predecir=np.array([[4.9,1.4], [6.3,4.9]])

resultados=[]

for i in range(0,len(redes)-1):
  model=fit_compile(redes[i], x, y)
  resultados1=model.predict(predecir)
  print(resultados1)
  index=i+1
  resultados.append([index, resultados1])
  print(resultados)

print(resultados)
print('\n-----------------------------\n')
print(tabulate(resultados, headers=('indice', 'resultados1', 'resultados2')))
# Out:
# Epoch 1/40
# c:\Users\shiku\Documents\IABD\PIA\redes_neuronales\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5070
# Epoch 2/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5037
# Epoch 3/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5010
# Epoch 4/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4984
# Epoch 5/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4959
# Epoch 6/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4933
# Epoch 7/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4907
# Epoch 8/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4880
# Epoch 9/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.48531
# Epoch 10/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4824
# Epoch 11/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4795
# Epoch 12/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4724
# Epoch 13/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4694
# Epoch 14/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4705
# Epoch 15/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4674
# Epoch 16/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4643
# Epoch 17/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4611
# Epoch 18/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.4580
# Epoch 19/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4549
# Epoch 20/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.45184
# Epoch 21/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4488
# Epoch 22/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4458
# Epoch 23/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4429
# Epoch 24/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.44004
# Epoch 25/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4371
# Epoch 26/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4343
# Epoch 27/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4315
# Epoch 28/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4287
# Epoch 29/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4260
# Epoch 30/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4234
# Epoch 31/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4207
# Epoch 32/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4181
# Epoch 33/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4155
# Epoch 34/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4129
# Epoch 35/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4104
# Epoch 36/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4079
# Epoch 37/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4054
# Epoch 38/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4029
# Epoch 39/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4004
# Epoch 40/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[0.82207936]
#  [0.73275673]]
# [[1, array([[0.82207936],
#        [0.73275673]], dtype=float32)]]
# Epoch 1/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2500
# Epoch 2/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2500
# Epoch 3/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2501
# Epoch 4/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2501
# Epoch 5/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2501
# Epoch 6/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2501
# Epoch 7/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2502
# Epoch 8/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2502
# Epoch 9/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2502
# Epoch 10/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2502
# Epoch 11/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2502
# Epoch 12/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2503
# Epoch 13/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2503
# Epoch 14/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2503
# Epoch 15/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2503
# Epoch 16/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2504
# Epoch 17/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2504
# Epoch 18/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2504
# Epoch 19/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.25040
# Epoch 20/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2504
# Epoch 21/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2505
# Epoch 22/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2505
# Epoch 23/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2505
# Epoch 24/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2505
# Epoch 25/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2505
# Epoch 26/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2506
# Epoch 27/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2506
# Epoch 28/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2506
# Epoch 29/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2506
# Epoch 30/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2507
# Epoch 31/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2507
# Epoch 32/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2506
# Epoch 33/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2507
# Epoch 34/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2507
# Epoch 35/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2508
# Epoch 36/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2508
# Epoch 37/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2508
# Epoch 38/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2508
# Epoch 39/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2508
# Epoch 40/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [[0.51158583]
#  [0.51158583]]
# [[1, array([[0.82207936],
#        [0.73275673]], dtype=float32)], [2, array([[0.51158583],
#        [0.51158583]], dtype=float32)]]
# Epoch 1/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2403
# Epoch 2/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2212
# Epoch 3/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2092
# Epoch 4/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1987
# Epoch 5/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1889
# Epoch 6/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1795
# Epoch 7/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.17023
# Epoch 8/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1615
# Epoch 9/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1527
# Epoch 10/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1440
# Epoch 11/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1350
# Epoch 12/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1261
# Epoch 13/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1159
# Epoch 14/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1049
# Epoch 15/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0951
# Epoch 16/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0860
# Epoch 17/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0778
# Epoch 18/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0700
# Epoch 19/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0629
# Epoch 20/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0565
# Epoch 21/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0506
# Epoch 22/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452
# Epoch 23/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0404
# Epoch 24/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0360
# Epoch 25/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0322
# Epoch 26/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0287
# Epoch 27/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255
# Epoch 28/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0228
# Epoch 29/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204
# Epoch 30/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181
# Epoch 31/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.0162
# Epoch 32/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0144
# Epoch 33/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125
# Epoch 34/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109
# Epoch 35/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097
# Epoch 36/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086
# Epoch 37/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076
# Epoch 38/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0068
# Epoch 39/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061
# Epoch 40/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [[0.06297431]
#  [0.97750694]]
# [[1, array([[0.82207936],
#        [0.73275673]], dtype=float32)], [2, array([[0.51158583],
#        [0.51158583]], dtype=float32)], [3, array([[0.06297431],
#        [0.97750694]], dtype=float32)]]
# Epoch 1/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2910
# Epoch 2/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2657
# Epoch 3/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2589
# Epoch 4/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2555
# Epoch 5/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2535
# Epoch 6/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2522
# Epoch 7/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2514
# Epoch 8/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2509
# Epoch 9/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2505
# Epoch 10/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2489
# Epoch 11/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2497
# Epoch 12/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2489
# Epoch 13/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2433
# Epoch 14/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2371
# Epoch 15/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2351
# Epoch 16/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2322
# Epoch 17/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.22958
# Epoch 18/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2264
# Epoch 19/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2229
# Epoch 20/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2186
# Epoch 21/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2134
# Epoch 22/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2103
# Epoch 23/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2061
# Epoch 24/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2018
# Epoch 25/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1976
# Epoch 26/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1933
# Epoch 27/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1890
# Epoch 28/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1846
# Epoch 29/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1802
# Epoch 30/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1758
# Epoch 31/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1713
# Epoch 32/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1668
# Epoch 33/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1622
# Epoch 34/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1577
# Epoch 35/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1531
# Epoch 36/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1485
# Epoch 37/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1439
# Epoch 38/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1394
# Epoch 39/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1348
# Epoch 40/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# [[0.42968893]
#  [0.81978834]]
# [[1, array([[0.82207936],
#        [0.73275673]], dtype=float32)], [2, array([[0.51158583],
#        [0.51158583]], dtype=float32)], [3, array([[0.06297431],
#        [0.97750694]], dtype=float32)], [4, array([[0.42968893],
#        [0.81978834]], dtype=float32)]]
# [[1, array([[0.82207936],
#        [0.73275673]], dtype=float32)], [2, array([[0.51158583],
#        [0.51158583]], dtype=float32)], [3, array([[0.06297431],
#        [0.97750694]], dtype=float32)], [4, array([[0.42968893],
#        [0.81978834]], dtype=float32)]]
#
# -----------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 57
#      55 print(resultados)
#      56 print('\n-----------------------------\n')
# ---> 57 print(tabulate(resultados, headers=('indice', 'resultados1', 'resultados2')))
#
# File c:\Users\shiku\Documents\IABD\PIA\redes_neuronales\.venv\Lib\site-packages\tabulate\__init__.py:2048, in tabulate(tabular_data, headers, tablefmt, floatfmt, intfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths, rowalign, maxheadercolwidths)
#    2045 if tabular_data is None:
#    2046     tabular_data = []
# -> 2048 list_of_lists, headers = _normalize_tabular_data(
#    2049     tabular_data, headers, showindex=showindex
#    2050 )
#    2051 list_of_lists, separating_lines = _remove_separating_lines(list_of_lists)
#    2053 if maxcolwidths is not None:
#
# File c:\Users\shiku\Documents\IABD\PIA\redes_neuronales\.venv\Lib\site-packages\tabulate\__init__.py:1471, in _normalize_tabular_data(tabular_data, headers, showindex)
#    1469 headers = list(map(str, headers))
#    1470 #    rows = list(map(list, rows))
# -> 1471 rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1473 # add or remove an index column
#    1474 showindex_is_a_str = type(showindex) in [str, bytes]
#
# File c:\Users\shiku\Documents\IABD\PIA\redes_neuronales\.venv\Lib\site-packages\tabulate\__init__.py:1471, in _normalize_tabular_data.<locals>.<lambda>(r)
#    1469 headers = list(map(str, headers))
#    1470 #    rows = list(map(list, rows))
# -> 1471 rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1473 # add or remove an index column
#    1474 showindex_is_a_str = type(showindex) in [str, bytes]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
